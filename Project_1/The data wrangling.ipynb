# %%
#import relevant libraries for the data analysis 
import pandas as pd 
import numpy as np
import folium 
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
print('libraries imported')
pd.set_option('display.max_columns', None)
# Out:
# libraries imported

# %%
#import the dataset
website_url='https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv'
Df= pd.read_csv(website_url, sep=',', error_bad_lines=False, index_col=False,dtype='unicode')
Df.head()
Df.tail()
# Out:
#        SEVERITYCODE             X            Y OBJECTID  INCKEY COLDETKEY  \
# 194668            2  -122.2908262  47.56540821   219543  309534    310814
# 194669            1  -122.3445262  47.69092352   219544  309085    310365
# 194670            2  -122.3066886  47.68304696   219545  311280    312640
# 194671            2  -122.3553167  47.67873428   219546  309514    310794
# 194672            1  -122.2893597  47.61101705   219547  308220    309500
#
#        REPORTNO   STATUS      ADDRTYPE INTKEY  \
# 194668  E871089  Matched         Block    NaN
# 194669  E876731  Matched         Block    NaN
# 194670  3809984  Matched  Intersection  24760
# 194671  3810083  Matched  Intersection  24349
# 194672  E868008  Matched         Block    NaN
#
#                                                LOCATION EXCEPTRSNCODE  \
# 194668  34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# 194669     AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# 194670                       20TH AVE NE AND NE 75TH ST
# 194671                    GREENWOOD AVE N AND N 68TH ST
# 194672     34TH AVE BETWEEN E MARION ST AND E SPRING ST
#
#        EXCEPTRSNDESC SEVERITYCODE.1                    SEVERITYDESC  \
# 194668           NaN              2                Injury Collision
# 194669           NaN              1  Property Damage Only Collision
# 194670           NaN              2                Injury Collision
# 194671           NaN              2                Injury Collision
# 194672           NaN              1  Property Damage Only Collision
#
#        COLLISIONTYPE PERSONCOUNT PEDCOUNT PEDCYLCOUNT VEHCOUNT  \
# 194668       Head On           3        0           0        2
# 194669    Rear Ended           2        0           0        2
# 194670     Left Turn           3        0           0        2
# 194671        Cycles           2        0           1        1
# 194672    Rear Ended           2        0           0        2
#
#                        INCDATE                INCDTTM  \
# 194668  2018/11/12 00:00:00+00  11/12/2018 8:12:00 AM
# 194669  2018/12/18 00:00:00+00  12/18/2018 9:14:00 AM
# 194670  2019/01/19 00:00:00+00   1/19/2019 9:25:00 AM
# 194671  2019/01/15 00:00:00+00   1/15/2019 4:48:00 PM
# 194672  2018/11/30 00:00:00+00  11/30/2018 3:45:00 PM
#
#                                    JUNCTIONTYPE SDOT_COLCODE  \
# 194668  Mid-Block (not related to intersection)           11
# 194669  Mid-Block (not related to intersection)           14
# 194670   At Intersection (intersection related)           11
# 194671   At Intersection (intersection related)           51
# 194672  Mid-Block (not related to intersection)           14
#
#                                              SDOT_COLDESC INATTENTIONIND  \
# 194668  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194669       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194670  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194671  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 194672       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
#
#        UNDERINFL  WEATHER ROADCOND LIGHTCOND PEDROWNOTGRNT SDOTCOLNUM  \
# 194668         N    Clear      Dry  Daylight           NaN        NaN
# 194669         N  Raining      Wet  Daylight           NaN        NaN
# 194670         N    Clear      Dry  Daylight           NaN        NaN
# 194671         N    Clear      Dry      Dusk           NaN        NaN
# 194672         N    Clear      Wet  Daylight           NaN        NaN
#
#        SPEEDING ST_COLCODE                                         ST_COLDESC  \
# 194668      NaN         24    From opposite direction - both moving - head-on
# 194669      NaN         13  From same direction - both going straight - bo...
# 194670      NaN         28  From opposite direction - one left turn - one ...
# 194671      NaN          5                       Vehicle Strikes Pedalcyclist
# 194672      NaN         14  From same direction - both going straight - on...
#
#        SEGLANEKEY CROSSWALKKEY HITPARKEDCAR
# 194668          0            0            N
# 194669          0            0            N
# 194670          0            0            N
# 194671       4308            0            N
# 194672          0            0            N

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  object
#  1   X               189339 non-null  object
#  2   Y               189339 non-null  object
#  3   OBJECTID        194673 non-null  object
#  4   INCKEY          194673 non-null  object
#  5   COLDETKEY       194673 non-null  object
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   object
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  object
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
#  16  PERSONCOUNT     194673 non-null  object
#  17  PEDCOUNT        194673 non-null  object
#  18  PEDCYLCOUNT     194673 non-null  object
#  19  VEHCOUNT        194673 non-null  object
#  20  INCDATE         194673 non-null  object
#  21  INCDTTM         194673 non-null  object
#  22  JUNCTIONTYPE    188344 non-null  object
#  23  SDOT_COLCODE    194673 non-null  object
#  24  SDOT_COLDESC    194673 non-null  object
#  25  INATTENTIONIND  29805 non-null   object
#  26  UNDERINFL       189789 non-null  object
#  27  WEATHER         189592 non-null  object
#  28  ROADCOND        189661 non-null  object
#  29  LIGHTCOND       189503 non-null  object
#  30  PEDROWNOTGRNT   4667 non-null    object
#  31  SDOTCOLNUM      114936 non-null  object
#  32  SPEEDING        9333 non-null    object
#  33  ST_COLCODE      194655 non-null  object
#  34  ST_COLDESC      189769 non-null  object
#  35  SEGLANEKEY      194673 non-null  object
#  36  CROSSWALKKEY    194673 non-null  object
#  37  HITPARKEDCAR    194673 non-null  object
# dtypes: object(38)
# memory usage: 56.4+ MB

# %%
missing_data=Df.isnull()
missing_data.head()
# Out:
#    SEVERITYCODE      X      Y  OBJECTID  INCKEY  COLDETKEY  REPORTNO  STATUS  \
# 0         False  False  False     False   False      False     False   False
# 1         False  False  False     False   False      False     False   False
# 2         False  False  False     False   False      False     False   False
# 3         False  False  False     False   False      False     False   False
# 4         False  False  False     False   False      False     False   False
#
#    ADDRTYPE  INTKEY  LOCATION  EXCEPTRSNCODE  EXCEPTRSNDESC  SEVERITYCODE.1  \
# 0     False   False     False          False           True           False
# 1     False    True     False           True           True           False
# 2     False    True     False           True           True           False
# 3     False    True     False          False           True           False
# 4     False   False     False           True           True           False
#
#    SEVERITYDESC  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0         False          False        False     False        False     False
# 1         False          False        False     False        False     False
# 2         False          False        False     False        False     False
# 3         False          False        False     False        False     False
# 4         False          False        False     False        False     False
#
#    INCDATE  INCDTTM  JUNCTIONTYPE  SDOT_COLCODE  SDOT_COLDESC  INATTENTIONIND  \
# 0    False    False         False         False         False            True
# 1    False    False         False         False         False            True
# 2    False    False         False         False         False            True
# 3    False    False         False         False         False            True
# 4    False    False         False         False         False            True
#
#    UNDERINFL  WEATHER  ROADCOND  LIGHTCOND  PEDROWNOTGRNT  SDOTCOLNUM  \
# 0      False    False     False      False           True        True
# 1      False    False     False      False           True       False
# 2      False    False     False      False           True       False
# 3      False    False     False      False           True        True
# 4      False    False     False      False           True       False
#
#    SPEEDING  ST_COLCODE  ST_COLDESC  SEGLANEKEY  CROSSWALKKEY  HITPARKEDCAR
# 0      True       False       False       False         False         False
# 1      True       False       False       False         False         False
# 2      True       False       False       False         False         False
# 3      True       False       False       False         False         False
# 4      True       False       False       False         False         False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# SEVERITYCODE
# False    194673
# Name: SEVERITYCODE, dtype: int64
#
# X
# False    189339
# True       5334
# Name: X, dtype: int64
#
# Y
# False    189339
# True       5334
# Name: Y, dtype: int64
#
# OBJECTID
# False    194673
# Name: OBJECTID, dtype: int64
#
# INCKEY
# False    194673
# Name: INCKEY, dtype: int64
#
# COLDETKEY
# False    194673
# Name: COLDETKEY, dtype: int64
#
# REPORTNO
# False    194673
# Name: REPORTNO, dtype: int64
#
# STATUS
# False    194673
# Name: STATUS, dtype: int64
#
# ADDRTYPE
# False    192747
# True       1926
# Name: ADDRTYPE, dtype: int64
#
# INTKEY
# True     129603
# False     65070
# Name: INTKEY, dtype: int64
#
# LOCATION
# False    191996
# True       2677
# Name: LOCATION, dtype: int64
#
# EXCEPTRSNCODE
# True     109862
# False     84811
# Name: EXCEPTRSNCODE, dtype: int64
#
# EXCEPTRSNDESC
# True     189035
# False      5638
# Name: EXCEPTRSNDESC, dtype: int64
#
# SEVERITYCODE.1
# False    194673
# Name: SEVERITYCODE.1, dtype: int64
#
# SEVERITYDESC
# False    194673
# Name: SEVERITYDESC, dtype: int64
#
# COLLISIONTYPE
# False    189769
# True       4904
# Name: COLLISIONTYPE, dtype: int64
#
# PERSONCOUNT
# False    194673
# Name: PERSONCOUNT, dtype: int64
#
# PEDCOUNT
# False    194673
# Name: PEDCOUNT, dtype: int64
#
# PEDCYLCOUNT
# False    194673
# Name: PEDCYLCOUNT, dtype: int64
#
# VEHCOUNT
# False    194673
# Name: VEHCOUNT, dtype: int64
#
# INCDATE
# False    194673
# Name: INCDATE, dtype: int64
#
# INCDTTM
# False    194673
# Name: INCDTTM, dtype: int64
#
# JUNCTIONTYPE
# False    188344
# True       6329
# Name: JUNCTIONTYPE, dtype: int64
#
# SDOT_COLCODE
# False    194673
# Name: SDOT_COLCODE, dtype: int64
#
# SDOT_COLDESC
# False    194673
# Name: SDOT_COLDESC, dtype: int64
#
# INATTENTIONIND
# True     164868
# False     29805
# Name: INATTENTIONIND, dtype: int64
#
# UNDERINFL
# False    189789
# True       4884
# Name: UNDERINFL, dtype: int64
#
# WEATHER
# False    189592
# True       5081
# Name: WEATHER, dtype: int64
#
# ROADCOND
# False    189661
# True       5012
# Name: ROADCOND, dtype: int64
#
# LIGHTCOND
# False    189503
# True       5170
# Name: LIGHTCOND, dtype: int64
#
# PEDROWNOTGRNT
# True     190006
# False      4667
# Name: PEDROWNOTGRNT, dtype: int64
#
# SDOTCOLNUM
# False    114936
# True      79737
# Name: SDOTCOLNUM, dtype: int64
#
# SPEEDING
# True     185340
# False      9333
# Name: SPEEDING, dtype: int64
#
# ST_COLCODE
# False    194655
# True         18
# Name: ST_COLCODE, dtype: int64
#
# ST_COLDESC
# False    189769
# True       4904
# Name: ST_COLDESC, dtype: int64
#
# SEGLANEKEY
# False    194673
# Name: SEGLANEKEY, dtype: int64
#
# CROSSWALKKEY
# False    194673
# Name: CROSSWALKKEY, dtype: int64
#
# HITPARKEDCAR
# False    194673
# Name: HITPARKEDCAR, dtype: int64

# %%
df_1=Df.drop(['SEVERITYCODE','EXCEPTRSNCODE','EXCEPTRSNDESC','INCKEY',
              'COLDETKEY','REPORTNO','STATUS','INTKEY','SEGLANEKEY','CROSSWALKKEY',
              'HITPARKEDCAR','SDOTCOLNUM'],axis=1)

# %%
df_1.dtypes
# Out:
# X                 object
# Y                 object
# OBJECTID          object
# ADDRTYPE          object
# LOCATION          object
# SEVERITYCODE.1    object
# SEVERITYDESC      object
# COLLISIONTYPE     object
# PERSONCOUNT       object
# PEDCOUNT          object
# PEDCYLCOUNT       object
# VEHCOUNT          object
# INCDATE           object
# INCDTTM           object
# JUNCTIONTYPE      object
# SDOT_COLCODE      object
# SDOT_COLDESC      object
# INATTENTIONIND    object
# UNDERINFL         object
# WEATHER           object
# ROADCOND          object
# LIGHTCOND         object
# PEDROWNOTGRNT     object
# SPEEDING          object
# ST_COLCODE        object
# ST_COLDESC        object
# dtype: object

# %%
df_1.rename(columns={'X':'Longitude','Y':'Latitude',
                     'SEVERITYCODE.1':'SEVERITYCODE'},inplace=True)

# %%
df_1
# Out:
#            Longitude     Latitude OBJECTID      ADDRTYPE  \
# 0       -122.3231484  47.70314032        1  Intersection
# 1       -122.3472943  47.64717249        2         Block
# 2         -122.33454  47.60787143        3         Block
# 3       -122.3348033  47.60480289        4         Block
# 4       -122.3064263  47.54573946        5  Intersection
# ...              ...          ...      ...           ...
# 194668  -122.2908262  47.56540821   219543         Block
# 194669  -122.3445262  47.69092352   219544         Block
# 194670  -122.3066886  47.68304696   219545  Intersection
# 194671  -122.3553167  47.67873428   219546  Intersection
# 194672  -122.2893597  47.61101705   219547         Block
#
#                                                LOCATION SEVERITYCODE  \
# 0                            5TH AVE NE AND NE 103RD ST            2
# 1            AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N            1
# 2           4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST            1
# 3              2ND AVE BETWEEN MARION ST AND MADISON ST            1
# 4                       SWIFT AVE S AND SWIFT AV OFF RP            2
# ...                                                 ...          ...
# 194668  34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST            2
# 194669     AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST            1
# 194670                       20TH AVE NE AND NE 75TH ST            2
# 194671                    GREENWOOD AVE N AND N 68TH ST            2
# 194672     34TH AVE BETWEEN E MARION ST AND E SPRING ST            1
#
#                           SEVERITYDESC COLLISIONTYPE PERSONCOUNT PEDCOUNT  \
# 0                     Injury Collision        Angles           2        0
# 1       Property Damage Only Collision     Sideswipe           2        0
# 2       Property Damage Only Collision    Parked Car           4        0
# 3       Property Damage Only Collision         Other           3        0
# 4                     Injury Collision        Angles           2        0
# ...                                ...           ...         ...      ...
# 194668                Injury Collision       Head On           3        0
# 194669  Property Damage Only Collision    Rear Ended           2        0
# 194670                Injury Collision     Left Turn           3        0
# 194671                Injury Collision        Cycles           2        0
# 194672  Property Damage Only Collision    Rear Ended           2        0
#
#        PEDCYLCOUNT VEHCOUNT                 INCDATE                 INCDTTM  \
# 0                0        2  2013/03/27 00:00:00+00    3/27/2013 2:54:00 PM
# 1                0        2  2006/12/20 00:00:00+00   12/20/2006 6:55:00 PM
# 2                0        3  2004/11/18 00:00:00+00  11/18/2004 10:20:00 AM
# 3                0        3  2013/03/29 00:00:00+00    3/29/2013 9:26:00 AM
# 4                0        2  2004/01/28 00:00:00+00    1/28/2004 8:04:00 AM
# ...            ...      ...                     ...                     ...
# 194668           0        2  2018/11/12 00:00:00+00   11/12/2018 8:12:00 AM
# 194669           0        2  2018/12/18 00:00:00+00   12/18/2018 9:14:00 AM
# 194670           0        2  2019/01/19 00:00:00+00    1/19/2019 9:25:00 AM
# 194671           1        1  2019/01/15 00:00:00+00    1/15/2019 4:48:00 PM
# 194672           0        2  2018/11/30 00:00:00+00   11/30/2018 3:45:00 PM
#
#                                    JUNCTIONTYPE SDOT_COLCODE  \
# 0        At Intersection (intersection related)           11
# 1       Mid-Block (not related to intersection)           16
# 2       Mid-Block (not related to intersection)           14
# 3       Mid-Block (not related to intersection)           11
# 4        At Intersection (intersection related)           11
# ...                                         ...          ...
# 194668  Mid-Block (not related to intersection)           11
# 194669  Mid-Block (not related to intersection)           14
# 194670   At Intersection (intersection related)           11
# 194671   At Intersection (intersection related)           51
# 194672  Mid-Block (not related to intersection)           14
#
#                                              SDOT_COLDESC INATTENTIONIND  \
# 0       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 1       MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN
# 2            MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
# 3       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 4       MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# ...                                                   ...            ...
# 194668  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194669       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END              Y
# 194670  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN
# 194671  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...            NaN
# 194672       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN
#
#        UNDERINFL   WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  \
# 0              N  Overcast      Wet                 Daylight           NaN
# 1              0   Raining      Wet  Dark - Street Lights On           NaN
# 2              0  Overcast      Dry                 Daylight           NaN
# 3              N     Clear      Dry                 Daylight           NaN
# 4              0   Raining      Wet                 Daylight           NaN
# ...          ...       ...      ...                      ...           ...
# 194668         N     Clear      Dry                 Daylight           NaN
# 194669         N   Raining      Wet                 Daylight           NaN
# 194670         N     Clear      Dry                 Daylight           NaN
# 194671         N     Clear      Dry                     Dusk           NaN
# 194672         N     Clear      Wet                 Daylight           NaN
#
#        SPEEDING ST_COLCODE                                         ST_COLDESC
# 0           NaN         10                                  Entering at angle
# 1           NaN         11  From same direction - both going straight - bo...
# 2           NaN         32                             One parked--one moving
# 3           NaN         23                   From same direction - all others
# 4           NaN         10                                  Entering at angle
# ...         ...        ...                                                ...
# 194668      NaN         24    From opposite direction - both moving - head-on
# 194669      NaN         13  From same direction - both going straight - bo...
# 194670      NaN         28  From opposite direction - one left turn - one ...
# 194671      NaN          5                       Vehicle Strikes Pedalcyclist
# 194672      NaN         14  From same direction - both going straight - on...
#
# [194673 rows x 26 columns]

# %%
missing_data_1=df_1.isnull()
missing_data_1.head()
# Out:
#    Longitude  Latitude  OBJECTID  ADDRTYPE  LOCATION  SEVERITYCODE  \
# 0      False     False     False     False     False         False
# 1      False     False     False     False     False         False
# 2      False     False     False     False     False         False
# 3      False     False     False     False     False         False
# 4      False     False     False     False     False         False
#
#    SEVERITYDESC  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0         False          False        False     False        False     False
# 1         False          False        False     False        False     False
# 2         False          False        False     False        False     False
# 3         False          False        False     False        False     False
# 4         False          False        False     False        False     False
#
#    INCDATE  INCDTTM  JUNCTIONTYPE  SDOT_COLCODE  SDOT_COLDESC  INATTENTIONIND  \
# 0    False    False         False         False         False            True
# 1    False    False         False         False         False            True
# 2    False    False         False         False         False            True
# 3    False    False         False         False         False            True
# 4    False    False         False         False         False            True
#
#    UNDERINFL  WEATHER  ROADCOND  LIGHTCOND  PEDROWNOTGRNT  SPEEDING  \
# 0      False    False     False      False           True      True
# 1      False    False     False      False           True      True
# 2      False    False     False      False           True      True
# 3      False    False     False      False           True      True
# 4      False    False     False      False           True      True
#
#    ST_COLCODE  ST_COLDESC
# 0       False       False
# 1       False       False
# 2       False       False
# 3       False       False
# 4       False       False

# %%
for column in missing_data_1.columns.values.tolist():
    print(column)
    print(missing_data_1[column].value_counts())
    print("")
# Out:
# Longitude
# False    189339
# True       5334
# Name: Longitude, dtype: int64
#
# Latitude
# False    189339
# True       5334
# Name: Latitude, dtype: int64
#
# OBJECTID
# False    194673
# Name: OBJECTID, dtype: int64
#
# ADDRTYPE
# False    192747
# True       1926
# Name: ADDRTYPE, dtype: int64
#
# LOCATION
# False    191996
# True       2677
# Name: LOCATION, dtype: int64
#
# SEVERITYCODE
# False    194673
# Name: SEVERITYCODE, dtype: int64
#
# SEVERITYDESC
# False    194673
# Name: SEVERITYDESC, dtype: int64
#
# COLLISIONTYPE
# False    189769
# True       4904
# Name: COLLISIONTYPE, dtype: int64
#
# PERSONCOUNT
# False    194673
# Name: PERSONCOUNT, dtype: int64
#
# PEDCOUNT
# False    194673
# Name: PEDCOUNT, dtype: int64
#
# PEDCYLCOUNT
# False    194673
# Name: PEDCYLCOUNT, dtype: int64
#
# VEHCOUNT
# False    194673
# Name: VEHCOUNT, dtype: int64
#
# INCDATE
# False    194673
# Name: INCDATE, dtype: int64
#
# INCDTTM
# False    194673
# Name: INCDTTM, dtype: int64
#
# JUNCTIONTYPE
# False    188344
# True       6329
# Name: JUNCTIONTYPE, dtype: int64
#
# SDOT_COLCODE
# False    194673
# Name: SDOT_COLCODE, dtype: int64
#
# SDOT_COLDESC
# False    194673
# Name: SDOT_COLDESC, dtype: int64
#
# INATTENTIONIND
# True     164868
# False     29805
# Name: INATTENTIONIND, dtype: int64
#
# UNDERINFL
# False    189789
# True       4884
# Name: UNDERINFL, dtype: int64
#
# WEATHER
# False    189592
# True       5081
# Name: WEATHER, dtype: int64
#
# ROADCOND
# False    189661
# True       5012
# Name: ROADCOND, dtype: int64
#
# LIGHTCOND
# False    189503
# True       5170
# Name: LIGHTCOND, dtype: int64
#
# PEDROWNOTGRNT
# True     190006
# False      4667
# Name: PEDROWNOTGRNT, dtype: int64
#
# SPEEDING
# True     185340
# False      9333
# Name: SPEEDING, dtype: int64
#
# ST_COLCODE
# False    194655
# True         18
# Name: ST_COLCODE, dtype: int64
#
# ST_COLDESC
# False    189769
# True       4904
# Name: ST_COLDESC, dtype: int64

# %%
df_1['Longitude']=df_1['Longitude'].astype('float')
df_1['Latitude']=df_1['Latitude'].astype('float')
df_1['OBJECTID']=df_1['OBJECTID'].astype('string')
df_1['ADDRTYPE']=df_1['ADDRTYPE'].astype('string')
df_1['LOCATION']=df_1['LOCATION'].astype('string')
df_1['SEVERITYCODE']=df_1['SEVERITYCODE'].astype('string')
df_1['SEVERITYDESC']=df_1['SEVERITYDESC'].astype('string')
df_1['COLLISIONTYPE']=df_1['COLLISIONTYPE'].astype('string')
df_1['PERSONCOUNT']=df_1['PERSONCOUNT'].astype('int')
df_1['PEDCOUNT']=df_1['PEDCOUNT'].astype('int')
df_1['PEDCYLCOUNT']=df_1['PEDCYLCOUNT'].astype('int')
df_1['VEHCOUNT']=df_1['VEHCOUNT'].astype('int')
df_1['INCDATE']=df_1['INCDATE'].astype('string')
df_1['INCDTTM']=df_1['INCDTTM'].astype('string')
df_1['JUNCTIONTYPE']=df_1['JUNCTIONTYPE'].astype('string')
df_1['SDOT_COLCODE']=df_1['SDOT_COLCODE'].astype('string')
df_1['SDOT_COLDESC']=df_1['SDOT_COLDESC'].astype('string')
df_1['INATTENTIONIND']=df_1['INATTENTIONIND'].astype('string')
df_1['UNDERINFL']=df_1['UNDERINFL'].astype('string')
df_1['WEATHER']=df_1['WEATHER'].astype('string')
df_1['ROADCOND']=df_1['ROADCOND'].astype('string')
df_1['LIGHTCOND']=df_1['LIGHTCOND'].astype('string')
df_1['PEDROWNOTGRNT']=df_1['PEDROWNOTGRNT'].astype('string')
df_1['SPEEDING']=df_1['SPEEDING'].astype('string')
df_1['ST_COLCODE']=df_1['ST_COLCODE'].astype('string')
df_1['ST_COLDESC']=df_1['ST_COLDESC'].astype('string')

# %%
df_1.dtypes
# Out:
# Longitude         float64
# Latitude          float64
# OBJECTID           string
# ADDRTYPE           string
# LOCATION           string
# SEVERITYCODE       string
# SEVERITYDESC       string
# COLLISIONTYPE      string
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            string
# INCDTTM            string
# JUNCTIONTYPE       string
# SDOT_COLCODE       string
# SDOT_COLDESC       string
# INATTENTIONIND     string
# UNDERINFL          string
# WEATHER            string
# ROADCOND           string
# LIGHTCOND          string
# PEDROWNOTGRNT      string
# SPEEDING           string
# ST_COLCODE         string
# ST_COLDESC         string
# dtype: object

# %%
location_statistic=df_1[['Longitude','Latitude','OBJECTID','PERSONCOUNT',
                       'PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']]
location_statistic
# Out:
#          Longitude   Latitude OBJECTID  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 0      -122.323148  47.703140        1            2         0            0
# 1      -122.347294  47.647172        2            2         0            0
# 2      -122.334540  47.607871        3            4         0            0
# 3      -122.334803  47.604803        4            3         0            0
# 4      -122.306426  47.545739        5            2         0            0
# ...            ...        ...      ...          ...       ...          ...
# 194668 -122.290826  47.565408   219543            3         0            0
# 194669 -122.344526  47.690924   219544            2         0            0
# 194670 -122.306689  47.683047   219545            3         0            0
# 194671 -122.355317  47.678734   219546            2         0            1
# 194672 -122.289360  47.611017   219547            2         0            0
#
#         VEHCOUNT
# 0              2
# 1              2
# 2              3
# 3              3
# 4              2
# ...          ...
# 194668         2
# 194669         2
# 194670         2
# 194671         1
# 194672         2
#
# [194673 rows x 7 columns]

# %%
latitude=47.64
longitude=-122.30

# %%
seattle_map=folium.Map(location=[latitude, longitude],zoom_start=11)
seattle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
serious_incidents=location_statistic.loc[location_statistic.PERSONCOUNT>10]
serious_incidents=serious_incidents.dropna()
serious_incidents
# Out:
#          Longitude   Latitude OBJECTID  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 93     -122.363032  47.548385      106           16         0            0
# 639    -122.335129  47.605159      722           11         0            0
# 966    -122.335783  47.665035     1102           12         0            0
# 1124   -122.409564  47.648628     1290           11         0            0
# 1650   -122.347270  47.677784     1898           17         0            0
# ...            ...        ...      ...          ...       ...          ...
# 185091 -122.338197  47.606835   208183           13         0            0
# 189316 -122.350465  47.613367   213338           34         0            0
# 190965 -122.334204  47.574386   215215           44         0            0
# 191624 -122.333822  47.545285   215975           12         0            0
# 191901 -122.331598  47.590311   216296           11         0            0
#
#         VEHCOUNT
# 93             2
# 639            2
# 966            4
# 1124           2
# 1650           5
# ...          ...
# 185091         2
# 189316         3
# 190965         2
# 191624         4
# 191901         2
#
# [229 rows x 7 columns]

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the serious incidents and add each to the incidents feature group

for lat, lng, in zip(serious_incidents.Latitude, serious_incidents.Longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
seattle_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_2=df_1[['INCDATE','INCDTTM','OBJECTID','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']]
df_2
# Out:
#                        INCDATE                 INCDTTM OBJECTID  PERSONCOUNT  \
# 0       2013/03/27 00:00:00+00    3/27/2013 2:54:00 PM        1            2
# 1       2006/12/20 00:00:00+00   12/20/2006 6:55:00 PM        2            2
# 2       2004/11/18 00:00:00+00  11/18/2004 10:20:00 AM        3            4
# 3       2013/03/29 00:00:00+00    3/29/2013 9:26:00 AM        4            3
# 4       2004/01/28 00:00:00+00    1/28/2004 8:04:00 AM        5            2
# ...                        ...                     ...      ...          ...
# 194668  2018/11/12 00:00:00+00   11/12/2018 8:12:00 AM   219543            3
# 194669  2018/12/18 00:00:00+00   12/18/2018 9:14:00 AM   219544            2
# 194670  2019/01/19 00:00:00+00    1/19/2019 9:25:00 AM   219545            3
# 194671  2019/01/15 00:00:00+00    1/15/2019 4:48:00 PM   219546            2
# 194672  2018/11/30 00:00:00+00   11/30/2018 3:45:00 PM   219547            2
#
#         PEDCOUNT  PEDCYLCOUNT  VEHCOUNT
# 0              0            0         2
# 1              0            0         2
# 2              0            0         3
# 3              0            0         3
# 4              0            0         2
# ...          ...          ...       ...
# 194668         0            0         2
# 194669         0            0         2
# 194670         0            0         2
# 194671         0            1         1
# 194672         0            0         2
#
# [194673 rows x 7 columns]

# %%
df_2['INCDATE']=pd.to_datetime(df_2['INCDATE'], format='%Y/%m/%d',errors='coerce')
annual_statistics=df_2['OBJECTID'].groupby([df_2['INCDATE'].dt.year.rename('Year')]).agg({'count'})
annual_statistics.rename(columns={'count':'Incidents'},inplace=True)
annual_statistics
# Out:
# <ipython-input-22-da77d660f4a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['INCDATE']=pd.to_datetime(df_2['INCDATE'], format='%Y/%m/%d',errors='coerce')
#       Incidents
# Year
# 2004      11865
# 2005      15115
# 2006      15188
# 2007      14456
# 2008      13660
# 2009      11734
# 2010      10808
# 2011      10919
# 2012      10907
# 2013      10577
# 2014      11841
# 2015      12995
# 2016      11659
# 2017      10873
# 2018      10419
# 2019       9412
# 2020       2245

# %%
annual_statistics.plot(kind='bar',figsize=(14,8))
plt.title('The Incidents in Seattle in last 16 years')
plt.ylabel('Numbers of the Incidents')
plt.xlabel('Year')
plt.show()

# %%
df_2['Hours']= pd.to_datetime(df_2['INCDTTM']).dt.hour
df_2

# %%
def f(x):
    if (x > 4) and (x <= 8):
        return 'Early Morning'
    elif (x > 8) and (x <= 12 ):
        return 'Morning'
    elif (x > 12) and (x <= 16):
        return'Noon'
    elif (x > 16) and (x <= 20) :
        return 'Eve'
    elif (x > 20) and (x <= 24):
        return'Night'
    elif (x <= 4):
        return'Late Night'

df_2['session'] = df_2['Hours'].apply(f)
df_2

# %%
Day_statistics=df_2['OBJECTID'].groupby([df_2['session']]).agg({'count'})
Day_statistics.rename(columns={'count':'Incidents'},inplace=True)
Day_statistics

# %%
Day_statistics.plot(kind='bar',figsize=(14,8),color='orange')
plt.title('The Incident Sessions in Seattle')
plt.ylabel('The Numbers of Incidents')
plt.xlabel('Time Session')

# %%
Day_statistics_1=df_2['PERSONCOUNT'].groupby([df_2['session']]).sum()
Day_statistics_1

# %%
Day_statistics_1.plot(kind='bar',figsize=(14,8),color='red')
plt.title('The involv')
plt.ylabel('The Number of People Involved in Incidents')
plt.xlabel('Time Session')

# %%
annual_statistic_2=df_2['PEDCOUNT'].groupby([df_2['INCDATE'].dt.year.rename('Year')]).sum().to_frame(name='Pedestrians').reset_index()
annual_statistic_3=df_2['PEDCYLCOUNT'].groupby([df_2['INCDATE'].dt.year.rename('Year')]).sum().to_frame(name='Bicycles').reset_index()
annual_statistic_4=df_2['VEHCOUNT'].groupby([df_2['INCDATE'].dt.year.rename('Year')]).sum().to_frame(name='Vehicles').reset_index()
annual_statistic_a=pd.concat([annual_statistic_2,annual_statistic_3,annual_statistic_4],axis=1).drop_duplicates().reset_index(drop=True)
annual_statistic_a
